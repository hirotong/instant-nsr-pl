# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
img = Image.open("./load/nerf_synthetic/miyuki/00_016.png")
img_rgb = np.array(img)[..., :3]
img_mask = np.array(img)[..., -1:]

# %%
img.show()

# %%
plt.imshow(img_rgb)
plt.show()
# Out:
# Unable to init server: Could not connect: Connection refused
#
# (eog:1620340): Gtk-WARNING **: 22:32:43.796: cannot open display: localhost:10.0

# %%
plt.imshow(img_mask)
plt.show()
